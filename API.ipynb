# %%
import requests
import json

# %%
url ="https://youtube.googleapis.com/youtube/v3/channels?part=contentDetails&forHandle=KhalidLidlissiDala&key=AIzaSyBCFQ9McnFuuJLNc6oJMiWSFrkn0rpJ9rg"

# %%
response = requests.get(url)
print(response)
print(response.json())
# Out:
# <Response [200]>
# {'kind': 'youtube#channelListResponse', 'etag': '5pqcKxw3uYWqhaARetYZzIn4JYs', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'x6vrgIQtId09_Y43ifrR18SaHL0', 'id': 'UCeuMT3QEwuCdRE8Tg58RCqg', 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UUeuMT3QEwuCdRE8Tg58RCqg'}}}]}

# %%
print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "kind": "youtube#channelListResponse",
#     "etag": "5pqcKxw3uYWqhaARetYZzIn4JYs",
#     "pageInfo": {
#         "totalResults": 1,
#         "resultsPerPage": 5
#     },
#     "items": [
#         {
#             "kind": "youtube#channel",
#             "etag": "x6vrgIQtId09_Y43ifrR18SaHL0",
#             "id": "UCeuMT3QEwuCdRE8Tg58RCqg",
#             "contentDetails": {
#                 "relatedPlaylists": {
#                     "likes": "",
#                     "uploads": "UUeuMT3QEwuCdRE8Tg58RCqg"
#                 }
#             }
#         }
#     ]
# }

# %%
print(response.json()["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"])
# Out:
# UUeuMT3QEwuCdRE8Tg58RCqg

# %%
def uploads_id():
    url ="https://youtube.googleapis.com/youtube/v3/channels?part=contentDetails&forHandle=KhalidLidlissiDala&key=AIzaSyBCFQ9McnFuuJLNc6oJMiWSFrkn0rpJ9rg"
    response = requests.get(url)
    return response.json()["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

# %%
res = uploads_id()
print(res)
# Out:
# UUeuMT3QEwuCdRE8Tg58RCqg

# %%
url="https://youtube.googleapis.com/youtube/v3/playlistItems?part=contentDetails&playlistId=UUeuMT3QEwuCdRE8Tg58RCqg&key=AIzaSyBCFQ9McnFuuJLNc6oJMiWSFrkn0rpJ9rg"
response=requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
# reponse=requests.get(url)
# print(response)
# #print(response.json())
# data = response.json()
# for item in data["items"]:
#     print(item["contentDetails"]["videoId"])

# %%
print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "kind": "youtube#playlistItemListResponse",
#     "etag": "6WQWp62ADz5GJOj8G1j_mnOzbGg",
#     "nextPageToken": "EAAaHlBUOkNBVWlFRFJET1VZMVJVSTBSRVl4TUVZNU0wUQ",
#     "items": [
#         {
#             "kind": "youtube#playlistItem",
#             "etag": "ajUC2eIvpEu8jQL66kPH4WE_EpM",
#             "id": "VVVldU1UM1FFd3VDZFJFOFRnNThSQ3FnLndqdjdZbGtzem1Z",
#             "contentDetails": {
#                 "videoId": "wjv7YlkszmY",
#                 "videoPublishedAt": "2026-03-14T17:09:49Z"
#             }
#         },
#         {
#             "kind": "youtube#playlistItem",
#             "etag": "2BTMnJGvavIsBAMcYrzpUdyKRiA",
#             "id": "VVVldU1UM1FFd3VDZFJFOFRnNThSQ3FnLkY3QzFkamxvdnNn",
#             "contentDetails": {
#                 "videoId": "F7C1djlovsg",
#                 "videoPublishedAt": "2026-03-07T23:54:07Z"
#             }
#         },
#         {
#             "kind": "youtube#playlistItem",
# ...

# %%
def get_playlist_id():
    try:        
        url = "https://youtube.googleapis.com/youtube/v3/channels?part=contentDetails&forHandle=KhalidLidlissiDala&key=AIzaSyBCFQ9McnFuuJLNc6oJMiWSFrkn0rpJ9rg"
        response = requests.get(url)
        response.raise_for_status()  # Check if the request was successful
        channel_playlistsId = response.json()["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
        return channel_playlistsId
    except requests.exceptions.RequestException as e:
        return f"An error occurred: {e}"
    
if __name__ == "__main__":
    playlist_id = get_playlist_id()
    print(playlist_id)
# Out:
# UUeuMT3QEwuCdRE8Tg58RCqg

# %%
def get_videos_ids(playlist_id):
    base_url =f"https://youtube.googleapis.com/youtube/v3/playlistItems?part=contentDetails&maxResults=50&playlistId={playlist_id}&key=AIzaSyBCFQ9McnFuuJLNc6oJMiWSFrkn0rpJ9rg"
    pageToken = None
    video_ids = []
    try:
        while True:
          url = base_url
          if pageToken:
              url += f"&pageToken={pageToken}"

          response = requests.get(url)
          response.raise_for_status()  # Check if the request was successful
          data = response.json()
          for item in data.get("items", []):
              video_ids.append(item["contentDetails"]["videoId"])

          pageToken = data.get("nextPageToken")

          if not pageToken:
              break
        return video_ids    

    except requests.exceptions.RequestException as e:
        raise Exception(f"An error occurred: {e}")    
   

if __name__ == "__main__":
    playlist_id = get_playlist_id()
    print(get_videos_ids(playlist_id))


print(len(get_videos_ids(playlist_id)))
# Out:
# ['wjv7YlkszmY', 'F7C1djlovsg', '6hGq2Vr_qfE', 'wOXAjZ6J4pU', 'qI0ibiDr3y8', 'NWXQilkT_TM', 'wbUaOQXtOgY', 'b_UiR0OqHrg', 'nE6lR1M6BV0', 'jX73qLO4K1E', 'V8-Ao8QNCvA', 'X-W4-CpcUsg', 'j_gtIbdxlDc', 'lgUzrBOIBZI', 'Aj_zV2HHAH8', '167yi92MOM4', 'rJI4r3oivoE', 'muSoqvTQ0c4', 'pANDfELmuh4', '4-vQgcsjViM', 'UnMPfqvTxCY', 'txZIugbUWlM', 'U5SRxIjKT_M', 'tvZX9hrM8n4', 'Bcg8BJWbSuY', 'KX_x5DR6p0g', '6Au5gJR-QrQ', 'Bk9gLvt7034', 'fGIC81OcgWY', 'tNfmMuJZdos', 'uL9Iq6ss55M', 'QPfxKeh213E', 'MfjxYvWtT14', 'u6eEbHU9bgo', 'lGzT5vBDUN4', 'qEYbyrOYJQw', '5zrOSXEkzW4', 'AjbAYUi2O_Q', 'nli1lwV86as', '52m0AuEZQuQ', 'trV4Sg_wbQg', 'cgFiNLn_69o', 'VkpTjiZTCDs', 'bHJgSJBkZ4c', 'RJmCO8PMGk0', '5lR86iBuZ0Q', 'EBXoONidbA4', 'ur9GCsEQvxU', 'vc_pvQcE0PQ', '2G1sBiOjIq8', 'HtiFBiZs3DE', 'NuuE76XuQEg', 'hN-kEtxdR0Q', 'QrQE6CouxfI', 'Pz6rPqLTaJI', '02IwmyZk7kQ', 'vmsEcFPaNpA', 'EC8M8P3ZQT0', 'LloghB4EeUk', 'AzM1FUNRtAM', 'LWenty42Dho', 'oICmmYkHacw', 'D296hguAfMY', 'iVUtffwYZ5s', '70MLaNAeTY0', 'QvAdBZnk8Yk', 'Q0DtLw
# ...

# %%
def batch_list(video_ids_lst, batch_size):
    for video_id in range(0, len(video_ids_lst), batch_size):
        yield video_ids_lst[video_id:video_id + batch_size]


def extract_video_details(video_ids):
    video_details = []
    for batch in batch_list(video_ids, 50):
        ids = ",".join(batch)
        url = f"https://youtube.googleapis.com/youtube/v3/videos?part=snippet,contentDetails,statistics&id={ids}&key=AIzaSyBCFQ9McnFuuJLNc6oJMiWSFrkn0rpJ9rg"
        try:
            response = requests.get(url)
            response.raise_for_status()  # Check if the request was successful
            data = response.json()
            for item in data.get("items", []):
                video_details.append({
                    "videoId": item["id"],
                    "title": item["snippet"]["title"],
                    "publishedAt": item["snippet"]["publishedAt"],
                    "duration": item["contentDetails"]["duration"],
                    "viewCount": item["statistics"].get("viewCount", 0),
                    "likeCount": item["statistics"].get("likeCount", 0),
                    "commentCount": item["statistics"].get("commentCount", 0)
                })
        except requests.exceptions.RequestException as e:
            raise Exception(f"An error occurred: {e}")
    return video_details

if __name__ == "__main__":
    playlist_id = get_playlist_id()
    video_ids = get_videos_ids(playlist_id)
    details = extract_video_details(video_ids)
    print(details)
# Out:
# [{'videoId': 'wjv7YlkszmY', 'title': 'وجدنا فطور رمضاني مع الواليد وكيف العادة بقينا بلا فطور 😅', 'publishedAt': '2026-03-14T17:09:49Z', 'duration': 'PT22M33S', 'viewCount': '259636', 'likeCount': '10012', 'commentCount': '261'}, {'videoId': 'F7C1djlovsg', 'title': 'سولتونا جاوبناكوم.. شحال تكاليف البرطمة ؟', 'publishedAt': '2026-03-07T23:54:07Z', 'duration': 'PT22M29S', 'viewCount': '171383', 'likeCount': '8092', 'commentCount': '302'}, {'videoId': '6hGq2Vr_qfE', 'title': 'توديع الواليدة قبل العمرة… انا والوليد غندوزو رمضان بلا بيها!🥲', 'publishedAt': '2026-02-27T21:54:23Z', 'duration': 'PT23M1S', 'viewCount': '171539', 'likeCount': '7590', 'commentCount': '213'}, {'videoId': 'wOXAjZ6J4pU', 'title': 'علاش رجعنا قبل ما نوصلو لـ جبل توبقال؟ التحدي سالا قبل ما يبدا 😪', 'publishedAt': '2026-02-23T17:54:45Z', 'duration': 'PT32M9S', 'viewCount': '164287', 'likeCount': '7091', 'commentCount': '207'}, {'videoId': 'qI0ibiDr3y8', 'title': 'اغرب تقديا ديال شهر رمضان!.. مكنتش متوقع هادشي☹️😅', '
# ...

# %%
import datetime
from datetime import date
def save_to_json(extracted_data):
    file_path = f"./data/YT_data_{date.today()}.json"

    with open(file_path, "w", encoding="utf-8") as json_file:
        json.dump(extracted_data, json_file, indent=4, ensure_ascii=False
        )

if __name__ == "__main__":
    playlist_id = get_playlist_id()
    video_ids = get_videos_ids(playlist_id)
    details = extract_video_details(video_ids)
    save_to_json(details)

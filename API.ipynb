# %%
import requests
import json

# %%
url ="https://youtube.googleapis.com/youtube/v3/channels?part=contentDetails&forHandle=topphysiquechimie&key=AIzaSyBCFQ9McnFuuJLNc6oJMiWSFrkn0rpJ9rg"

# %%
response = requests.get(url)
print(response)
print(response.json())
# Out:
# <Response [200]>
# {'kind': 'youtube#channelListResponse', 'etag': 'bKHm0Slj53NzkcXc23GYiYRigac', 'pageInfo': {'totalResults': 1, 'resultsPerPage': 5}, 'items': [{'kind': 'youtube#channel', 'etag': 'UsLPzhdAQaUsYhSSDeV06zoW1_w', 'id': 'UCrdfDuefkw6y1GD6ytIbb1Q', 'contentDetails': {'relatedPlaylists': {'likes': '', 'uploads': 'UUrdfDuefkw6y1GD6ytIbb1Q'}}}]}

# %%
print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "kind": "youtube#channelListResponse",
#     "etag": "bKHm0Slj53NzkcXc23GYiYRigac",
#     "pageInfo": {
#         "totalResults": 1,
#         "resultsPerPage": 5
#     },
#     "items": [
#         {
#             "kind": "youtube#channel",
#             "etag": "UsLPzhdAQaUsYhSSDeV06zoW1_w",
#             "id": "UCrdfDuefkw6y1GD6ytIbb1Q",
#             "contentDetails": {
#                 "relatedPlaylists": {
#                     "likes": "",
#                     "uploads": "UUrdfDuefkw6y1GD6ytIbb1Q"
#                 }
#             }
#         }
#     ]
# }

# %%
print(response.json()["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"])
# Out:
# UUrdfDuefkw6y1GD6ytIbb1Q

# %%
def uploads_id():
    url ="https://youtube.googleapis.com/youtube/v3/channels?part=contentDetails&forHandle=topphysiquechimie&key=AIzaSyBCFQ9McnFuuJLNc6oJMiWSFrkn0rpJ9rg"
    response = requests.get(url)
    return response.json()["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]

# %%
res = uploads_id()
print(res)
# Out:
# UUrdfDuefkw6y1GD6ytIbb1Q

# %%
url="https://youtube.googleapis.com/youtube/v3/playlistItems?part=contentDetails&playlistId=UUeuMT3QEwuCdRE8Tg58RCqg&key=AIzaSyBCFQ9McnFuuJLNc6oJMiWSFrkn0rpJ9rg"
response=requests.get(url)
print(response)
# Out:
# <Response [200]>

# %%
# reponse=requests.get(url)
# print(response)
# #print(response.json())
# data = response.json()
# for item in data["items"]:
#     print(item["contentDetails"]["videoId"])

# %%
print(json.dumps(response.json(), indent=4))
# Out:
# {
#     "kind": "youtube#playlistItemListResponse",
#     "etag": "6WQWp62ADz5GJOj8G1j_mnOzbGg",
#     "nextPageToken": "EAAaHlBUOkNBVWlFRFJET1VZMVJVSTBSRVl4TUVZNU0wUQ",
#     "items": [
#         {
#             "kind": "youtube#playlistItem",
#             "etag": "ajUC2eIvpEu8jQL66kPH4WE_EpM",
#             "id": "VVVldU1UM1FFd3VDZFJFOFRnNThSQ3FnLndqdjdZbGtzem1Z",
#             "contentDetails": {
#                 "videoId": "wjv7YlkszmY",
#                 "videoPublishedAt": "2026-03-14T17:09:49Z"
#             }
#         },
#         {
#             "kind": "youtube#playlistItem",
#             "etag": "2BTMnJGvavIsBAMcYrzpUdyKRiA",
#             "id": "VVVldU1UM1FFd3VDZFJFOFRnNThSQ3FnLkY3QzFkamxvdnNn",
#             "contentDetails": {
#                 "videoId": "F7C1djlovsg",
#                 "videoPublishedAt": "2026-03-07T23:54:07Z"
#             }
#         },
#         {
#             "kind": "youtube#playlistItem",
#             "etag": "4KxPLCLfhcNoCDu_ABHfDj8sLvA",
#             "id": "VVVldU1UM1FFd3VDZFJFOFRnNThSQ3FnLjZoR3EyVnJfcWZF",
#             "contentDetails": {
#                 "videoId": "6hGq2Vr_qfE",
#                 "videoPublishedAt": "2026-02-27T21:54:23Z"
#             }
#         },
#         {
#             "kind": "youtube#playlistItem",
#             "etag": "AjBeREKPEdRKaqC2bT0noGFHYAA",
#             "id": "VVVldU1UM1FFd3VDZFJFOFRnNThSQ3FnLndPWEFqWjZKNHBV",
#             "contentDetails": {
#                 "videoId": "wOXAjZ6J4pU",
#                 "videoPublishedAt": "2026-02-23T17:54:45Z"
#             }
#         },
#         {
#             "kind": "youtube#playlistItem",
#             "etag": "E4z14_usyHJ0UI9tl6txG41qYgw",
#             "id": "VVVldU1UM1FFd3VDZFJFOFRnNThSQ3FnLnFJMGliaURyM3k4",
#             "contentDetails": {
#                 "videoId": "qI0ibiDr3y8",
#                 "videoPublishedAt": "2026-02-19T18:33:13Z"
#             }
#         }
#     ],
#     "pageInfo": {
#         "totalResults": 296,
#         "resultsPerPage": 5
#     }
# }

# %%
def get_playlist_id():
    try:        
        url = "https://youtube.googleapis.com/youtube/v3/channels?part=contentDetails&forHandle=topphysiquechimie&key=AIzaSyBCFQ9McnFuuJLNc6oJMiWSFrkn0rpJ9rg"
        response = requests.get(url)
        response.raise_for_status()  # Check if the request was successful
        channel_playlistsId = response.json()["items"][0]["contentDetails"]["relatedPlaylists"]["uploads"]
        return channel_playlistsId
    except requests.exceptions.RequestException as e:
        return f"An error occurred: {e}"
    
if __name__ == "__main__":
    playlist_id = get_playlist_id()
    print(playlist_id)
# Out:
# UUrdfDuefkw6y1GD6ytIbb1Q

# %%
def get_videos_ids(playlist_id):
    base_url =f"https://youtube.googleapis.com/youtube/v3/playlistItems?part=contentDetails&maxResults=50&playlistId={playlist_id}&key=AIzaSyBCFQ9McnFuuJLNc6oJMiWSFrkn0rpJ9rg"
    pageToken = None
    video_ids = []
    try:
        while True:
          url = base_url
          if pageToken:
              url += f"&pageToken={pageToken}"

          response = requests.get(url)
          response.raise_for_status()  # Check if the request was successful
          data = response.json()
          for item in data.get("items", []):
              video_ids.append(item["contentDetails"]["videoId"])

          pageToken = data.get("nextPageToken")

          if not pageToken:
              break
        return video_ids    

    except requests.exceptions.RequestException as e:
        raise Exception(f"An error occurred: {e}")    
   

if __name__ == "__main__":
    playlist_id = get_playlist_id()
    print(get_videos_ids(playlist_id))


print(len(get_videos_ids(playlist_id)))

# %%
def batch_list(video_ids_lst, batch_size):
    for video_id in range(0, len(video_ids_lst), batch_size):
        yield video_ids_lst[video_id:video_id + batch_size]


def extract_video_details(video_ids):
    video_details = []
    for batch in batch_list(video_ids, 50):
        ids = ",".join(batch)
        url = f"https://youtube.googleapis.com/youtube/v3/videos?part=snippet,contentDetails,statistics&id={ids}&key=AIzaSyBCFQ9McnFuuJLNc6oJMiWSFrkn0rpJ9rg"
        try:
            response = requests.get(url)
            response.raise_for_status()  # Check if the request was successful
            data = response.json()
            for item in data.get("items", []):
                video_details.append({
                    "videoId": item["id"],
                    "title": item["snippet"]["title"],
                    "publishedAt": item["snippet"]["publishedAt"],
                    "duration": item["contentDetails"]["duration"],
                    "viewCount": item["statistics"].get("viewCount", 0),
                    "likeCount": item["statistics"].get("likeCount", 0),
                    "commentCount": item["statistics"].get("commentCount", 0)
                })
        except requests.exceptions.RequestException as e:
            raise Exception(f"An error occurred: {e}")
    return video_details

if __name__ == "__main__":
    playlist_id = get_playlist_id()
    video_ids = get_videos_ids(playlist_id)
    details = extract_video_details(video_ids)
    print(details)
# Out:
# [{'videoId': 'UamojHpGv18', 'title': 'étude de quelques instruments optiques 2 année  collège ', 'publishedAt': '2026-05-08T21:14:34Z', 'duration': 'PT8M29S', 'viewCount': '1864', 'likeCount': '82', 'commentCount': '43'}, {'videoId': 'd8R129bNIiw', 'title': '6 mai 2026', 'publishedAt': '2026-05-06T15:26:48Z', 'duration': 'PT12M45S', 'viewCount': '1597', 'likeCount': '70', 'commentCount': '42'}, {'videoId': 'EwgnAM0Qsx8', 'title': 'association des conducteurs ohmiques tronc commun', 'publishedAt': '2026-05-04T15:09:47Z', 'duration': 'PT28M16S', 'viewCount': '20536', 'likeCount': '749', 'commentCount': '165'}, {'videoId': 'm842y0z66Ek', 'title': 'la résistance électrique 1 année collège ', 'publishedAt': '2026-05-03T20:34:26Z', 'duration': 'PT15M13S', 'viewCount': '3788', 'likeCount': '129', 'commentCount': '27'}, {'videoId': '8LYsNGQvhKA', 'title': 'exercices le poids et la masse 3 année collège ', 'publishedAt': '2026-05-01T18:43:33Z', 'duration': 'PT12M58S', 'viewCount': '2209', 'likeCount': '71', 'commentCount': '23'}, {'videoId': 'tUryfFvgSKY', 'title': "exercices équilibre d'un solide soumis à deux forces ", 'publishedAt': '2026-04-30T23:30:49Z', 'duration': 'PT15M27S', 'viewCount': '1726', 'likeCount': '52', 'commentCount': '14'}, {'videoId': '8Rlmz8WYTog', 'title': 'exercices le courant électrique continu tronc commun série 1', 'publishedAt': '2026-04-25T19:51:11Z', 'duration': 'PT17M32S', 'viewCount': '21586', 'likeCount': '567', 'commentCount': '50'}, {'videoId': 'pvvDYIwQa54', 'title': "la loi des noeuds la loi d'additivité des tensions 1 année collège ", 'publishedAt': '2026-04-24T20:33:12Z', 'duration': 'PT13M28S', 'viewCount': '7040', 'likeCount': '198', 'commentCount': '36'}, {'videoId': 'y27aN-pbS3I', 'title': 'exercices réactions acido-basiques 1bac série 1', 'publishedAt': '2026-04-22T23:55:11Z', 'duration': 'PT19M58S', 'viewCount': '7041', 'likeCount': '208', 'commentCount': '30'}, {'videoId': 'QfM6VWjv4IY', 'title': 'exercices notion de forces 3 année collège ', 'publishedAt': '2026-04-20T22:23:03Z', 'duration': 'PT9M28S', 'viewCount': '10001', 'likeCount': '316', 'commentCount': '35'}, {'videoId': '2d1P5DOsxMk', 'title': 'exercices champ magnétique 1bac  série 1 ', 'publishedAt': '2026-04-17T22:18:35Z', 'duration': 'PT24M49S', 'viewCount': '39255', 'likeCount': '1115', 'commentCount': '160'}, {'videoId': 'Tn19KPtlBfQ', 'title': 'les lentilles minces 2 année collège ', 'publishedAt': '2026-04-16T20:18:20Z', 'duration': 'PT23M54S', 'viewCount': '50561', 'likeCount': '1517', 'commentCount': '221'}, {'videoId': 'bYwsCiSXUkA', 'title': 'exercices : le courant électrique continu 1 année collège ', 'publishedAt': '2026-04-05T15:39:25Z', 'duration': 'PT11M23S', 'viewCount': '25914', 'likeCount': '514', 'commentCount': '65'}, {'videoId': 'FwiWKic74YA', 'title': 'le courant électrique continu 1 année collège ', 'publishedAt': '2026-03-31T22:46:04Z', 'duration': 'PT21M54S', 'viewCount': '42884', 'likeCount': '1078', 'commentCount': '205'}, {'videoId': '1jc07UoLyUg', 'title': 'exercices : chute verticale 2bac option PC et S.M : série 1 ', 'publishedAt': '2026-03-29T15:07:32Z', 'duration': 'PT22M59S', 'viewCount': '34914', 'likeCount': '933', 'commentCount': '75'}, {'videoId': 'riDAZbBOqeM', 'title': 'exercices : transformations spontanées dans les piles : 2bac :série 1', 'publishedAt': '2026-03-28T15:22:26Z', 'duration': 'PT24M50S', 'viewCount': '21708', 'likeCount': '525', 'commentCount': '32'}, {'videoId': 'LGghYpiAMDM', 'title': 'exercices : application de la propagation de la lumière : 2 année collège ', 'publishedAt': '2026-03-23T12:59:06Z', 'duration': 'PT11M8S', 'viewCount': '23502', 'likeCount': '492', 'commentCount': '47'}, {'videoId': '3XFfoInUpWk', 'title': 'exercices : propagation de la lumière : 2 année collège ', 'publishedAt': '2026-03-22T16:56:28Z', 'duration': 'PT7M47S', 'viewCount': '9548', 'likeCount': '204', 'commentCount': '19'}, {'videoId': 'ncb0rSgenr8', 'title': 'champ magnétique créé par un cour ...

# %%
import datetime
from datetime import date
def save_to_json(extracted_data):
    file_path = f"./data/YT_data_{date.today()}.json"

    with open(file_path, "w", encoding="utf-8") as json_file:
        json.dump(extracted_data, json_file, indent=4, ensure_ascii=False
        )

if __name__ == "__main__":
    playlist_id = get_playlist_id()
    video_ids = get_videos_ids(playlist_id)
    details = extract_video_details(video_ids)
    save_to_json(details)
